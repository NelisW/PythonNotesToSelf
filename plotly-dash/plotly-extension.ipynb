# %% [markdown]
# # plotly-extension
#
#     conda install -c conda-forge plotly
#     jupyter labextension install @jupyterlab/plotly-extension
#     jupyter labextension uninstall @jupyterlab/plotly-extension
#
# https://plot.ly/python/offline/
# https://github.com/jupyterlab/jupyter-renderers/tree/master/packages/plotly-extension

# %%
import plotly
import numpy as np
import plotly.offline as py
from plotly import graph_objs as go
py.init_notebook_mode(connected=True)
print(plotly.__version__)
# 2.0.6

# Simple sine function
x = np.linspace(0,2*np.pi)
y = np.sin(x)
trace = go.Scatter(x=x,y=y)
py.iplot([trace])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# 3.6.1

# %% [markdown]
# ## plotly

# %%
import plotly
from IPython.display import display
import json


def Plotly(data=[], layout={}):
    bundle = {}
    bundle['application/vnd.plotly.v1+json'] = {
        'data': data,
        'layout': layout,
    }
    display(bundle, raw=True)

data = [
    {'x': [1999, 2000, 2001, 2002], 'y': [10, 15, 13, 17], 'type': 'scatter'},
    {'x': [1999, 2000, 2001, 2002], 'y': [16, 5, 11, 9], 'type': 'scatter'}
]

layout = {
    'title': 'Sales Growth',
    'xaxis': {'title': 'Year', 'showgrid': False, 'zeroline': False},
    'yaxis': {'title': 'Percent', 'showline': False}
}

Plotly(data, layout)

# %% [markdown]
# ## plotly
#
# Using [plotly](https://github.com/plotly/plotly.py) library

# %%
def Plotly(data=[], layout={}):
    bundle = {}
    bundle['application/vnd.plotly.v1+json'] = {
        'data': json.loads(json.dumps(data, cls=plotly.utils.PlotlyJSONEncoder)),
        'layout': json.loads(json.dumps(layout, cls=plotly.utils.PlotlyJSONEncoder)),
    }
    display(bundle, raw=True)
    
trace = plotly.graph_objs.Heatmap(z=[[1, 20, 30],
                      [20, 1, 60],
                      [30, 60, 1]])
data=[trace]
Plotly(data)

# %%
import plotly
import sys
from IPython.display import display
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)         # initiate notebook for offline plot
import json
sys.path.append("W:/cms/green/red/user/tools/python/ossimutils")
import ossimtools

def Plotly(data=[], layout={}):
    bundle = {}
    bundle['application/vnd.plotly.v1+json'] = {
        'data': data,
        'layout': layout,
    }
    display(bundle, raw=True)
filename = 'W:/cms/green/red/user/tools/TrajectoryCalculator-Simple/PythonNotebooks/data/complexAlt.traj'  
df = ossimtools.read1DIntpol(filename)    
data = [
    {'x': list(df['time'].values), 'y': list(df['x'].values), 'type': 'scatter','name':'x'},
    {'x': list(df['time'].values), 'y': list(df['y'].values), 'type': 'scatter','name':'y'},
]
layout = {
    'title': 'Trajectory',
    'xaxis': {'x': 'Time', 'showgrid': True, 'zeroline': False},
    'yaxis': {'y': 'Position', 'showline': False}
}

# Plotly(data, layout)
plotly.offline.iplot(data)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ae7c06eceaf6> in <module>
#      16     display(bundle, raw=True)
#      17 filename = 'W:/cms/green/red/user/tools/TrajectoryCalculator-Simple/PythonNotebooks/data/complexAlt.traj'
# ---> 18 df = ossimtools.read1DIntpol(filename)
#      19 data = [
#      20     {'x': list(df['time'].values), 'y': list(df['x'].values), 'type': 'scatter','name':'x'},
#
# ...
